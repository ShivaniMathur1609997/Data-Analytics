# %% [markdown]
# Analytics - Analyzing the data and giving meaningful insights from raw data

# %% [markdown]
# HR - Human resource
#
# HR Analytics - Analysis made by HR by seeing some data.

# %% [markdown]
# Customer churn === the number of customers who are at notice period

# %%
import pandas as pd

# %%
data = pd.read_csv("people.csv")

# %%
data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
data.head(5) # to see the initial rows
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
data.tail(5)   # to see the last rows
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
data.shape
# Out:
# (14999, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
# Data preprocessing :
#identify and treating of missing values or null values

data.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
data.isnull()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
#Data can be manipulated by two things basically and they should be managed
#1.Null values
#2.Duplicate values

# %%
# What if we have null values present-------------- manage my null values
# How we can update null values?
#1. drop the values
#2. Fill with mean(average) , median(centre most after sorting) , mode(most repetative)

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14994     True
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# Length: 14999, dtype: bool

# %%
data[data.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
data = data.drop_duplicates()

# %%
data.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
data.shape
# Out:
# (11991, 10)

# %%
#Our data is prepared now for analysis
# Correlation -------- Relationship among different variables
# range of correlation (-1 to 1)
# Types:
# 1. Positive(+) ----- if one variable is increasing other is also increasing, decreasign also
#      a. highly correlated
#      b. nominal 
# 2. Negative(-) ------if one in increasing other is decreasing and vice versa
#      a. higly correlated
#      b. nominal
# 3. Zero ---------- no connection of one feature with other

# %%
data.corr()
# this is known as Correlation Matrix
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (5,5))
sns.heatmap(data.corr(), cmap = "rainbow", annot = True)
plt.savefig("Correlation")
#plt.show()

# %%
data.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
fig = plt.subplots(figsize = (10,15))
plt.subplot(3,2,1)
plt.subplots_adjust(hspace = 1.0)
sns.countplot(x='dept', data= data, hue = "left")
plt.xticks(rotation = 90)
plt.show()

# 0 means not leaving the company
# 1 means they are at notice period

# %%
#Analysis from this is people from sales,technical,support at at high rate of churning
#Conclusion ----- 1. sales environment is very bad
#                 2.we need to incentivise people in sales, tech and support teams the most?
#                 3. Plese prioritize sales,technical,support

# %%
fig = plt.subplots(figsize = (10,15))
plt.subplot(3,2,1)
plt.subplots_adjust(hspace = 1.0)
sns.countplot(x='salary', data= data, hue = "left")
plt.xticks(rotation = 90)
plt.show()

# %%
#Analysis ---- people with low and medium salary are churning the most
#Recomendation to CEO------- provide incentives and hikes for elligible candidates

# %%
fig = plt.subplots(figsize = (10,15))
plt.subplot(3,2,1)
plt.subplots_adjust(hspace = 1.0)
sns.countplot(x='timeSpent.company', data= data, hue = "left")
plt.xticks(rotation = 90)
plt.show()

# %%
#Analysis: Between exp of 3 to 6 people are leaving the most
#Recommendation to CEO : Prioritize these people with their demands

# %%
# rest features do it by yourself
